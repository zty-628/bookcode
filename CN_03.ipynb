# %%
# This notebook is auto-generated from LaTeX Python examples.
# The first cell defines benign placeholder variables so that many examples run without NameError.
# You can safely edit or remove them.
filename = "demo.txt"
mode = "w"
text = "hello world"
numbers = [1, 2, 3]
items = ["a", "b", "c"]
data = {"a": 1, "b": 2}
def dummy_func(*args, **kwargs): 
    return None

# %%
# --- Example 1 ---
name = input("请输入您的名字：")
print("你好，" + name + "！")
# Out:
# 你好，ww！

# %%
# --- Example 2 ---
age = 20

if age >= 18:
    print("You are eligible to vote.")
elif age >= 13:
    print("You are a teenager.")
else:
    print("You are a child.")
# Out:
# You are eligible to vote.

# %%
# --- Example 3 ---
temperature = 75
is_sunny = True

if temperature > 70 and is_sunny:
    print("It's a beautiful day!")
# Out:
# It's a beautiful day!

# %%
# --- Example 4 ---
score = 82

if score >= 60:
    if score >= 90:
        print("Grade: A")
    elif score >= 80:
        print("Grade: B")
    else:
        print("Grade: C")
else:
    print("Failing grade")
# Out:
# Grade: B

# %%
# --- Example 5 ---
roll_sum = int(input("Enter sum of dice roll: "))

if roll_sum in [7, 11]:
    print("You win!")
elif roll_sum in [2, 3, 12]:
    print("You lose.")
else:
    print("Roll again.")
# Out:
# You lose.

# %%
# --- Example 6 ---
for item in sequence:
    # 处理 item
# Out:
#   Cell In[8], line 3
#     # 处理 item
#              ^
# _IncompleteInputError: incomplete input

# %%
# --- Example 7 ---
fruits = ["apple", "banana", "cherry"]

for fruit in fruits:
    print(f"I like {fruit}")
# Out:
# I like apple
# I like banana
# I like cherry

# %%
# --- Example 8 ---
count = 0

while count < 5:
    print(count)
    count += 1  # 避免无限循环
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# --- Example 9 ---
for num in range(10):
    if num == 5:
        break
    print(num)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# --- Example 10 ---
for num in range(5):
    if num == 3:
        continue
    print(num)
# Out:
# 0
# 1
# 2
# 4

# %%
# --- Example 11 ---
for i in range(3):
    for j in range(2):
        print(f"i={i}, j={j}")
# Out:
# i=0, j=0
# i=0, j=1
# i=1, j=0
# i=1, j=1
# i=2, j=0
# i=2, j=1

# %%
# --- Example 12 ---
###修改
count = 0

while count < 5:
    print(count)
    count = count+1
    # 缺少计数更新，导致无限循环
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# --- Example 13 ---
def function_name(parameters):
    # 代码块
    return result  # 可选

# %%
# --- Example 14 ---
def greet(name):
    print(f"Hello, {name}!")

greet("Alice")
# Out:
# Hello, Alice!

# %%
# --- Example 15 ---
def add(x, y):
    return x + y

sum = add(5, 3)
print(sum)  # 输出：8
# Out:
# 8

# %%
# --- Example 16 ---
def square(num):
    return num * num

print(square(4))  # 16
print(square(10)) # 100
# Out:
# 16
# 100

# %%
# --- Example 17 ---
def greet(name="Guest"):
    print(f"Hello, {name}!")

greet()
greet("Bob")
# Out:
# Hello, Guest!
# Hello, Bob!

# %%
# --- Example 18 ---
def calculator(num1, num2, op):
    if op == '+':
        return num1 + num2
    elif op == '-':
        return num1 - num2
    elif op == '*':
        return num1 * num2
    elif op == '/':
        if num2 != 0:
            return num1 / num2
        else:
            return "Cannot divide by zero"
    else:
        return "Invalid operator"

print(calculator(10, 5, '+'))  # 15
print(calculator(10, 0, '/'))  # Cannot divide by zero
# Out:
# 15
# Cannot divide by zero

# %%
# --- Example 19 ---
def is_even(num):
    if num % 2 == 0:
        return True
    return False

numbers = [1, 2, 3, 4]
for n in numbers:
    if is_even(n):
        print(f"{n} is even")
# Out:
# 2 is even
# 4 is even

# %%
# --- Example 20 ---
colors = ["red", "green", "blue"]
print(colors) # 输出: red
# Out:
# ['red', 'green', 'blue']

# %%
# --- Example 21 ---
colors.append("purple")
print(colors) # ['red', 'green', 'blue', 'purple']
colors.pop()
print(colors) # ['red', 'green', 'blue']
# Out:
# ['red', 'green', 'blue', 'purple']
# ['red', 'green', 'blue']

# %%
# --- Example 22 ---
location_visits = {}
# 使用坐标（元组）作为键
location_visits[(40.7128, 74.0060)] = "New York City"
location_visits[(34.0522, 118.2437)] = "Los Angeles"
print(location_visits)
# Out:
# {(40.7128, 74.006): 'New York City', (34.0522, 118.2437): 'Los Angeles'}

# %%
# --- Example 23 ---
person = {
    "name": "Alice",
    "age": 30,
    "city": "New York"
}
print(person["name"]) # 输出: Alice
# Out:
# Alice

# %%
# --- Example 24 ---
employees = {
    "001": {"name": "Bob", "department": "Sales"},
    "002": {"name": "Sara", "department": "IT"},
}
print(employees["001"]["department"]) # 输出: Sales
# Out:
# Sales

# %%
# --- Example 25 ---
squares = {x: x*x for x in range(5)}
print(squares) # {0:0, 1:1, 2:4, 3:9, 4:16}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
# --- Example 26 ---
unique_visitors = set(["Alice", "Bob", "Alice"])
print(unique_visitors) # {'Alice', 'Bob'}
# Out:
# {'Alice', 'Bob'}

# %%
# --- Example 27 ---
for key in person:
    print(key, person[key])

for key, value in person.items():
    print(key, value)
# Out:
# name Alice
# age 30
# city New York
# name Alice
# age 30
# city New York

# %%
# --- Example 28 ---

grades = {
    "Alice": [85, 90, 78],
    "Bob": [96, 88, 92],
}

for student, scores in grades.items():
    avg = sum(scores) / len(scores)
    print(f"{student}'s average is {avg:.2f}")
# Out:
# Alice's average is 84.33
# Bob's average is 92.00

# %%
# --- Example 29 ---
inventory = [
    {"item": "apple", "price": 0.5, "quantity": 100},
    {"item": "banana", "price": 0.3, "quantity": 150},
]

total_value = 0
for product in inventory:
    total_value += product["price"] * product["quantity"]

print(f"Total inventory value: ${total_value:.2f}")
# Out:
# Total inventory value: $95.00

# %%
# --- Example 30 ---
with open("example.txt", "r") as f:
    content = f.read()
    print(content)
# Out:
# Generated at 2025-09-19T13:55:33.513038Z
# kbrfweqcv vduhjqtie ccc utnwwio fkpdqv blqzdp qkrhazjzn sywykgfsi
# tlmoxu hypm smye oxkskv rkrovmk pxluxo iztjor gfyx
# cyrzrhm omoct ehasfsd oazqc qwb raxoasz lvij agrosfy

# %%
# --- Example 31 ---
with open("example.txt", "r") as f:
    for line in f:
        line = line.strip() # 移除末尾的换行符和空格
        print(line)
# Out:
# Generated at 2025-09-19T13:55:33.513038Z
# kbrfweqcv vduhjqtie ccc utnwwio fkpdqv blqzdp qkrhazjzn sywykgfsi
# tlmoxu hypm smye oxkskv rkrovmk pxluxo iztjor gfyx
# cyrzrhm omoct ehasfsd oazqc qwb raxoasz lvij agrosfy

# %%
# --- Example 32 ---
with open("example.txt") as f:
    line = f.readline()
    while line:
        print(line.strip())
        line = f.readline()
# Out:
# Generated at 2025-09-19T13:55:33.513038Z
# kbrfweqcv vduhjqtie ccc utnwwio fkpdqv blqzdp qkrhazjzn sywykgfsi
# tlmoxu hypm smye oxkskv rkrovmk pxluxo iztjor gfyx
# cyrzrhm omoct ehasfsd oazqc qwb raxoasz lvij agrosfy

# %%
# --- Example 33 ---
with open("data.txt", "r") as file:
    for line in file:
        print(line.strip())
# 此处无需显式调用 file.close()
# Out:
# header line
# row0,88
# row1,79
# row2,7
# row3,97
# row4,64

# %%
# --- Example 34 ---
with open("data.csv") as f:
    for line in f:
        row = line.strip().split(",")
        print(row)
# Out:
# ['id', 'name', 'score']
# ['1', 'Alice', '85']
# ['2', 'Bob', '92']
# ['3', 'Charlie', '78']

# %%
# --- Example 35 ---
try:
    with open("nofile.txt") as f:
        content = f.read()
except FileNotFoundError:
    print("文件不存在，请检查文件名。")
except IOError:
    print("发生IO错误。")
# Out:
# 文件不存在，请检查文件名。

# %%
# --- Example 36 ---
try:
    # 可能发生异常的代码块
    x = int(input("Enter a number: "))
    result = 10 / x
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
except ValueError:
    print("Error: Invalid input; please enter an integer.")
# Out:
# Error: Cannot divide by zero.

# %%
# --- Example 37 ---
try:
    f = open("data.txt")
    num = int(input("Enter a number: "))
    result = 10 / num
except FileNotFoundError:
    print("Error: data.txt file not found.")
except ValueError:
    print("Error: Please enter a valid whole number.")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# Error: Please enter a valid whole number.

# %%
# --- Example 38 ---
try:
    print("Trying to open file...")
    f = open("data.txt")
except FileNotFoundError:
    print("File not found!")
else:
    print("File opened successfully.")
    f.close()
finally:
    print("Finished attempting file operation.")
# Out:
# Trying to open file...
# File opened successfully.
# Finished attempting file operation.

# %%
# --- Example 39 ---
def check_age(age):
    if age < 0:
        raise ValueError("Age cannot be negative.")
    print(f"Age is {age}")

try:
    check_age(-5)
except ValueError as ve:
    print(f"Caught an exception: {ve}")
# Out:
# Caught an exception: Age cannot be negative.

# %%
# --- Example 40 ---
class NegativeAgeError(Exception):
    pass

def set_age(age):
    if age < 0:
        raise NegativeAgeError("Negative age is not valid.")

try:
    set_age(-10)
except NegativeAgeError as nae:
    print(f"Custom exception caught: {nae}")
# Out:
# Custom exception caught: Negative age is not valid.

# %%
# --- Example 41 ---
try:
    with open("data.csv") as file:
        data = file.read()
    number = int(input("Enter a number: "))
    print(f"Result: {10 / number}")
except FileNotFoundError as e:
    print("Error: Data file missing.")
except ValueError as e:
    print("Error: Input must be a number.")
except ZeroDivisionError as e:
    print("Error: Cannot divide by zero.")
else:
    print("Operation succeeded.")
finally:
    print("Finished processing.")
# Out:
# Result: 0.1
# Operation succeeded.
# Finished processing.

# %%
# --- Example 42 ---
try:
    with open("nofile.csv") as file:
        data = file.read()
except (FileNotFoundError, PermissionError) as e:
    print(f"File error: {e}")
# Out:
# File error: [Errno 2] No such file or directory: 'nofile.csv'

# %%
# --- Example 43 ---
while True:
    try:
        num = int(input("Enter a positive integer: "))
        if num <= 0:
            raise ValueError("Number must be positive.")
    except ValueError as e:
        print(f"Invalid input: {e}")
    else:
        print(f"Thank you! You entered {num}.")
        break
# Out:
# Thank you! You entered 12.

# %%
# --- Example 44 ---
def greet():
    print("Hello!")

say_hello = greet # 将函数赋值给一个变量
say_hello() # 通过新变量调用函数
# Out:
# Hello!

# %%
# --- Example 45 ---
def decorator(func):
    def wrapper():
        print("Before calling the function.")
        func()
        print("After calling the function.")
    return wrapper

def say_hello():
    print("Hello!")

say_hello = decorator(say_hello)
say_hello()
# Out:
# Before calling the function.
# Hello!
# After calling the function.

# %%
# --- Example 46 ---
def decorator(func):
    def wrapper():
        print("Before calling the function.")
        func()
        print("After calling the function.")
    return wrapper

@decorator
def say_hello():
    print("Hello!")

say_hello()
# Out:
# Before calling the function.
# Hello!
# After calling the function.

# %%
# --- Example 47 ---
def decorator(func):
    def wrapper(*args, **kwargs):
        print("Before calling the function.")
        result = func(*args, **kwargs)
        print("After calling the function.")
        return result
    return wrapper

@decorator
def greet(name):
    print(f"Hello, {name}!")

greet("Alice")
# Out:
# Before calling the function.
# Hello, Alice!
# After calling the function.

# %%
# --- Example 48 ---
import functools

def decorator(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        print("Before calling the function.")
        result = func(*args, **kwargs)
        print("After calling the function.")
        return result
    return wrapper

# %%
# --- Example 49 ---
import functools

def log_calls(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        print(f"Calling {func.__name__} with args {args} and kwargs {kwargs}")
        result = func(*args, **kwargs)
        print(f"{func.__name__} returned {result}")
        return result
    return wrapper

@log_calls
def add(x, y):
    return x + y

add(3, 4)
# Out:
# Calling add with args (3, 4) and kwargs {}
# add returned 7
# 7

# %%
# --- Example 50 ---
import functools

def repeat(num_times):
    def decorator_repeat(func):
        @functools.wraps(func)
        def wrapper(*args, **kwargs):
            for _ in range(num_times):
                func(*args, **kwargs)
        return wrapper
    return decorator_repeat

@repeat(3)
def greet(name):
    print(f"Hello {name}")

greet("Bob")
# Out:
# Hello Bob
# Hello Bob
# Hello Bob

# %%
# --- Example 51 ---
def decorator_one(func):
    def wrapper(*args, **kwargs):
        print("Decorator One is running")
        return func(*args, **kwargs)
    return wrapper

def decorator_two(func):
    def wrapper(*args, **kwargs):
        print("Decorator Two is running")
        return func(*args, **kwargs)
    return wrapper

@decorator_one
@decorator_two
def my_function():
    print("Hello from my_function")

my_function()
# Out:
# Decorator One is running
# Decorator Two is running
# Hello from my_function

# %%
# --- Example 52 ---
class CountCalls:
    def __init__(self, func):
        self.func = func
        self.num_calls = 0

    def __call__(self, *args, **kwargs):
        self.num_calls += 1
        print(f"Call {self.num_calls} of {self.func.__name__}")
        return self.func(*args, **kwargs)

@CountCalls
def say_hello():
    print("Hello!")

say_hello()
say_hello()
# Out:
# Call 1 of say_hello
# Hello!
# Call 2 of say_hello
# Hello!

# %%
# --- Example 53 ---
from flask import Flask
app = Flask(__name__)

@app.route('/')
def home():
    return "Welcome Home!"

# %%
# --- Example 54 ---
import functools

def debug_method(func):
    @functools.wraps(func)
    def wrapper(self, *args, **kwargs):
        print(f"Calling method {func.__name__}")
        return func(self, *args, **kwargs)
    return wrapper

class Calculator:
    @debug_method
    def add(self, x, y):
        return x + y

calc = Calculator()
calc.add(5, 7)
# Out:
# Calling method add
# 12
